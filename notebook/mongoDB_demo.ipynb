# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1           28                   0
# 1   2    Male   76                1            3                   0
# 2   3    Male   47                1           28                   0
# 3   4    Male   21                1           11                   1
# 4   5  Female   29                1           41                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes           40454                    26      217
# 1    1-2 Year             No           33536                    26      183
# 2   > 2 Years            Yes           38294                    26       27
# 3    < 1 Year             No           28619                   152      203
# 4    < 1 Year             No           27496                   152       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://harnish:harnish@1408@cluster0.y92o4so.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# ---------------------------------------------------------------------------
# InvalidURI                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = pymongo.MongoClient(CONNECTION_URL)
#       2 data_base = client[DB_NAME]
#       3 collection = data_base[COLLECTION_NAME]
#
# File c:\Users\DELL\Desktop\MLOPS\Car_Insuracnce(mlops proj)\venv\Lib\site-packages\pymongo\synchronous\mongo_client.py:797, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     792 for entity in self._host:
#     793     # A hostname can only include a-z, 0-9, '-' and '.'. If we find a '/'
#     794     # it must be a URI,
#     795     # https://en.wikipedia.org/wiki/Hostname#Restrictions_on_valid_host_names
#     796     if "/" in entity:
# --> 797         res = _validate_uri(
#     798             entity,
#     799             port,
#     800             validate=True,
#     801             warn=True,
#     802             normalize=False,
#     803             srv_max_hosts=srv_max_hosts,
#     804         )
#     805         is_srv = entity.startswith(SRV_SCHEME)
#     806         self._seeds.update(res["nodelist"])
#
# File c:\Users\DELL\Desktop\MLOPS\Car_Insuracnce(mlops proj)\venv\Lib\site-packages\pymongo\uri_parser_shared.py:512, in _validate_uri(uri, default_port, validate, warn, normalize, srv_max_hosts)
#     510 if "@" in host_part:
#     511     userinfo, _, hosts = host_part.rpartition("@")
# --> 512     user, passwd = parse_userinfo(userinfo)
#     513 else:
#     514     hosts = host_part
#
# File c:\Users\DELL\Desktop\MLOPS\Car_Insuracnce(mlops proj)\venv\Lib\site-packages\pymongo\uri_parser_shared.py:85, in parse_userinfo(userinfo)
#      75 """Validates the format of user information in a MongoDB URI.
#      76 Reserved characters that are gen-delimiters (":", "/", "?", "#", "[",
#      77 "]", "@") as per RFC 3986 must be escaped.
#    (...)     82 :param userinfo: A string of the form <username>:<password>
#      83 """
#      84 if "@" in userinfo or userinfo.count(":") > 1 or _unquoted_percent(userinfo):
# ---> 85     raise InvalidURI(
#      86         "Username and password must be escaped according to "
#      87         "RFC 3986, use urllib.parse.quote_plus"
#      88     )
#      90 user, _, passwd = userinfo.partition(":")
#      91 # No password is expected with GSSAPI authentication.
#
# InvalidURI: Username and password must be escaped according to RFC 3986, use urllib.parse.quote_plus
